# %%
# create input
list1 = [1,2]

# %%
# consume input
for i in list1:
    print(i)

# %%
# create other input
list2 = [3,4]

# %%
# consume other input 
for i in list2:
    print(i)

# %%
# int input
int1 = 1

# %%
# int consumer
print(int1)
# Out:
# 1

# %%
# other int input
int2 = 2

# %%
# other int consumer
print(int2)
# Out:
# 2
