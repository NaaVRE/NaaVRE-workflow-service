# %%
param_a = 'a'
param_b = 'b'

# %%
# test param a
print(param_a)
a = param_a
# Out:
# a

# %%
# test param b
print(param_b)
b = param_b
# Out:
# b

# %%
# test param consume values
print(a, b)
# Out:
# a b
